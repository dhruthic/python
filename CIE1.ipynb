# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('C:/Users/dacg lab 2/Desktop/mtcars.csv')
plt.hist(df['mpg'],bins=10,edgecolor='black')
plt.title('Histogram')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.show()

hist,bin_edges=np.histogram(df['mpg'],bins=10)
max_freq_bin_edges=[np.argmax(hist)]
print(max_freq_bin_edges)
# Out:
# [2]

# %%
plt.scatter(df['wt'],df['mpg'],color='blue')
plt.xlabel('Weight of car(1000lbs)')
plt.ylabel('Miles per gallon (mpg)')
plt.title('Scatter plot of weight vs MPG')
plt.show()

# %%
transmission_counts=df['am'].value_counts()
plt.bar(transmission_counts.index, transmission_counts.values,color='yellow')
plt.xlabel('Trensmission Type')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Transmission Type')
plt.xticks([0,1],['Automatic','Mannual'])
plt.show()

# %%
plt.boxplot(df['mpg'],vert=False)
plt.xlabel('MPG')
plt.title('Boxplot')
plt.show()

five_number_summary=df['mpg'].describe(percentiles=[0.25,0.5,0.75])[['min','25%','50%','max']]
five_number_summary
# Out:
# min    10.400
# 25%    15.425
# 50%    19.200
# max    33.900
# Name: mpg, dtype: float64

# %% [markdown]
# # Rainfall

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/dacg lab 2/Desktop/district wise rainfall normal.csv")
df.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/dacg lab 2/Desktop/district wise rainfall normal.csv")
sorted_df=df.sort_values(by='ANNUAL',ascending=False)

highest=sorted_df.iloc[0,1]
print("Higest rainfall",highest)
# Out:
# Higest rainfall TAMENGLONG

# %%
new_df=df.drop(['Jan-Feb','Mar-May','Jun-Sep'],axis=1)
new_df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
import pandas as pd
new_df=df.drop(['ANNUAL'],axis=1)
tabel=pd.pivot_table(new_df,index=['STATE_UT_NAME'])
tabel
# Out:
# C:\Users\dacg lab 2\AppData\Local\Temp\ipykernel_4900\3866736373.py:3: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   tabel=pd.pivot_table(new_df,index=['STATE_UT_NAME'])
#                                     APR         AUG         DEC        FEB  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   86.966667  385.300000  159.733333  33.266667
# ANDHRA PRADESH                19.873913  179.426087   15.565217   7.352174
# ARUNACHAL PRADESH            275.162500  378.600000   35.956250  93.293750
# ASSAM                        181.266667  377.370370   11.440741  31.714815
# BIHAR                         16.865789  289.481579    5.786842   9.278947
# CHANDIGARH                    14.800000  287.500000   23.400000  38.900000
# CHATISGARH                    13.116667  375.338889    5.811111  10.472222
# ...
